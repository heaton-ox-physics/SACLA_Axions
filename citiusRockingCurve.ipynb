# %%
### Rocking curve measurement - to be refined once we know motor names etc...
import os 
import sys
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
from math import *
import stpy
#### Import SACLA python library
# os.system("module load python/SACLA_python-3.7")
# os.system("python3")
import dbpy
import stpy
# import ippy

# %%
rockingCurveData = np.load("citiusRockingCurve_BL2_r255550.npy")
rotationStagePositions = []
intensity = []
for i in range(np.shape(rockingCurveData)[0]):
    rotationStagePositions.append(rockingCurveData[i][0])
    intensity.append(rockingCurveData[i][1])

plt.plot(rotationStagePositions,intensity)
